# %%
from syn_markush import *
# Out:
# main_dir /mnt/d/wsl_backend/CarsiChemIE/synthesis_data_script

# %%
idx = 0
cdk_plugin = get_cdk_plugin()
original_smiles = "CN(C)C\C=C\C(=O)Nc3cc1c(Nc(cc2Cl)ccc2F)ncnc1cc3OC4COCC4"
kwargs = {
    "is_dash" : True, 
    "is_wave_line" : False, 
    "dash_line" : False
}


image, result_dict = random_generate_rgroup_type_2(
                                                    idx = idx,
                                                    original_smiles = original_smiles,
                                                    cdk_plugin = cdk_plugin,
                                                    **kwargs
                                                    )
# import ipdb
# ipdb.set_trace()

# image, result_dict = random_generate_rgroup_type_2(
#                                                 idx = idx,
#                                                 original_smiles = original_smiles,
#                                                 cdk_plugin = cdk_plugin,
#                                                 )
image
# Out:
# Deprecated method call: scyjava.config.add_endpoints(). Please modify scyjava.config.endpoints directly instead.
# {'is_wave_line': False, 'is_dash': True, 'dash_line': False}
# <PIL.Image.Image image mode=RGB size=768x768>

# %%
from PIL import Image, ImageDraw, ImageFont
draw = ImageDraw.Draw(image)
font_size = 30
offset_size = font_size//3
font = ImageFont.truetype("font/Arial.ttf", font_size)
for i in range(len(result_dict["0"]["graph"]["coords"])):
    x, y = result_dict["0"]["graph"]["coords"][i]
    label = result_dict["0"]["graph"]["symbols"][i]
    draw.text((x-offset_size, y-offset_size), label, fill="red", font=font)
image
# Out:
# <PIL.Image.Image image mode=RGB size=768x768>

# %%
idx = 0
cdk_plugin = get_cdk_plugin()
original_smiles = "CN(C)C\C=C\C(=O)Nc3cc1c(Nc(cc2Cl)ccc2F)ncnc1cc3OC4COCC4"
kwargs = {
    "is_dash" : False, 
    "is_wave_line" : True, 
    "dash_line" : False
}


image, result_dict = random_generate_rgroup_type_2(
                                                    idx = idx,
                                                    original_smiles = original_smiles,
                                                    cdk_plugin = cdk_plugin,
                                                    **kwargs
                                                    )
# import ipdb
# ipdb.set_trace()

# image, result_dict = random_generate_rgroup_type_2(
#                                                 idx = idx,
#                                                 original_smiles = original_smiles,
#                                                 cdk_plugin = cdk_plugin,
#                                                 )
image
# Out:
# Deprecated method call: scyjava.config.add_endpoints(). Please modify scyjava.config.endpoints directly instead.
# {'is_wave_line': True, 'is_dash': False, 'dash_line': False}
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=768x768>

# %%
from PIL import Image, ImageDraw, ImageFont
draw = ImageDraw.Draw(image)
font_size = 30
offset_size = font_size//3
font = ImageFont.truetype("font/Arial.ttf", font_size)
for i in range(len(result_dict["0"]["graph"]["coords"])):
    x, y = result_dict["0"]["graph"]["coords"][i]
    label = result_dict["0"]["graph"]["symbols"][i]
    draw.text((x-offset_size, y-offset_size), label, fill="red", font=font)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=768x768>

# %%
idx = 0
cdk_plugin = get_cdk_plugin()
original_smiles = "CN(C)C\C=C\C(=O)Nc3cc1c(Nc(cc2Cl)ccc2F)ncnc1cc3OC4COCC4"
kwargs = {
    "is_dash" : False, 
    "is_wave_line" : False, 
    "dash_line" : True
}


image, result_dict = random_generate_rgroup_type_2(
                                                    idx = idx,
                                                    original_smiles = original_smiles,
                                                    cdk_plugin = cdk_plugin,
                                                    **kwargs
                                                    )
# import ipdb
# ipdb.set_trace()

# image, result_dict = random_generate_rgroup_type_2(
#                                                 idx = idx,
#                                                 original_smiles = original_smiles,
#                                                 cdk_plugin = cdk_plugin,
#                                                 )
image
# Out:
# Deprecated method call: scyjava.config.add_endpoints(). Please modify scyjava.config.endpoints directly instead.
# {'is_wave_line': False, 'is_dash': False, 'dash_line': True}
# <PIL.Image.Image image mode=RGB size=768x768>
